# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crop_yield.csv')
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df.shape
# Out:
# (19689, 10)

# %%
df.sample(5)
# Out:
#              Crop  Crop_Year       Season              State      Area  \
# 17609     Sesamum       2003  Kharif       Jammu and Kashmir    5744.0
# 9989        Jowar       2006  Kharif           Uttar Pradesh  231290.0
# 982    Horse-gram       2001  Rabi               West Bengal    3681.0
# 13546    Soyabean       2013  Kharif             Uttarakhand    9172.0
# 1365    Sugarcane       2003  Whole Year           Karnataka  243341.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide      Yield
# 17609        2699           1430.3    568541.12    1378.56   0.438000
# 9989       238052            590.5  29538045.90   50883.80   1.114500
# 982          3167           1556.6    375940.53     957.06   0.651111
# 13546       14374           1735.4   1325262.28    2476.44   1.109167
# 1365     16015440            867.6  24085892.18   58401.84  72.127600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(8,5))
df['Crop'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Crop Distribution')
plt.xlabel('Crop')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
df['Season'].value_counts().plot(kind='bar', color='blue')
plt.title('Season Distribution')
plt.xlabel('Season')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
df['State'].value_counts().plot(kind='bar', color='darkblue')
plt.title('State Distribution')
plt.xlabel('State')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Yield'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Yield Distribution')
plt.xlabel('Yield')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Area'], df['Production'], color='green')
plt.title('Production vs Area')
plt.xlabel('Area')
plt.ylabel('Production')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Annual_Rainfall'], df['Production'], color='purple')
plt.title('Production vs Annual Rainfall')
plt.xlabel('Annual Rainfall)')
plt.ylabel('Production')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.bar(df['State'], df['Production'], color='yellow', edgecolor='black')
plt.title('Production vs State')
plt.xlabel('State')
plt.ylabel('Production')
# Out:
# Text(0, 0.5, 'Production')

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Fertilizer'], df['Yield'], label='Fertilizer', color='blue')
plt.scatter(df['Pesticide'], df['Yield'], label='Pesticide', color='red')
plt.title('Yield vs Fertilizer and Pesticide')
plt.xlabel('Fertilizer / Pesticide (kg per hectare)')
plt.ylabel('Yield (tons per hectare)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Yield'], df['Production'], color='purple', edgecolor='black')
plt.title('Production vs Yield')
plt.xlabel('Yield')
plt.ylabel('Production')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Area'], df['Yield'], color='green')
plt.title('Yield vs Area')
plt.xlabel('Area')
plt.ylabel('Yield')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.bar(df['State'], df['Yield'], color='yellow')
plt.title('Yield vs State')
plt.xlabel('State')
plt.ylabel('Yield')
# Out:
# Text(0, 0.5, 'Yield')
