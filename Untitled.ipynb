# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crop_yield.csv')

# %%
df.shape
# Out:
# (19689, 10)

# %%
df.sample(5)
# Out:
#                     Crop  Crop_Year       Season           State      Area  \
# 19275          Groundnut       2006  Winter               Odisha    3535.0
# 2924        Sweet potato       2009  Whole Year            Assam    6806.0
# 14534          Arhar/Tur       2015  Kharif            Telangana  247514.0
# 4485   Moong(Green Gram)       2015  Rabi             Puducherry       9.0
# 509           Horse-gram       2000  Rabi         Andhra Pradesh   64789.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide     Yield
# 19275        4056           1716.9    451454.85     777.70  0.965789
# 2924        23969           1727.1   1060510.92    1157.02  3.410741
# 14534      103903            747.9  39084935.74   81679.62  0.496667
# 4485           10           1980.6      1421.19       2.97  1.110000
# 509         13492            935.6   6360336.13   16845.14  0.209545

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(df['State'])
#df['State'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: xlabel='count', ylabel='State'>

# %%
plt.figure(figsize = (10,20))
sns.countplot(df['Crop'])
# Out:
# <Axes: xlabel='count', ylabel='Crop'>

# %%
sns.countplot(df['Season'])
# Out:
# <Axes: xlabel='count', ylabel='Season'>

# %%
plt.hist(df['Crop_Year'],bins=10)
# Out:
# (array([1706., 1522., 1616., 2421., 1675., 1724., 2777., 1963., 2106.,
#         2179.]),
#  array([1997. , 1999.3, 2001.6, 2003.9, 2006.2, 2008.5, 2010.8, 2013.1,
#         2015.4, 2017.7, 2020. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Crop_Year'])
# Out:
# C:\Users\91887\AppData\Local\Temp\ipykernel_15496\2958069569.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Crop_Year'])
# <Axes: xlabel='Crop_Year', ylabel='Density'>

# %%
sns.boxplot(df['Crop_Year'])
# Out:
# <Axes: ylabel='Crop_Year'>

# %%
sns.boxplot(df['Production'])
# Out:
# <Axes: ylabel='Production'>

# %%
sns.boxplot(df['Yield'])
# Out:
# <Axes: ylabel='Yield'>

# %%
df['Production'].min()
# Out:
# 0

# %%
df['Production'].max()
# Out:
# 6326000000

# %%
df['Yield'].min()
# Out:
# 0.0

# %%
df['Yield'].max()
# Out:
# 21105.0

# %%
df['Production'].skew()
# Out:
# 19.299193411606723

# %%
sns.scatterplot(Crop_Field['total_bill'], tips['tip'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.scatterplot(tips['total_bill'], tips['tip'])
#
# NameError: name 'tips' is not defined
